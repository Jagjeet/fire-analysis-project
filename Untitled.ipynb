# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import sqlite3
import sqlalchemy as sqla
import scipy.stats as st
from scipy.stats import linregress
from api_keys import air_key

# %%
con = sqlite3.connect("./Resources/FPA_FOD_20170508.sqlite")
fire_data = pd.read_sql_query("SELECT OBJECTID, FOD_ID, FPA_ID, FIRE_YEAR, FIPS_NAME, FIRE_NAME, FIRE_SIZE, DISCOVERY_DATE, FIRE_CODE, STAT_CAUSE_DESCR, CONT_DATE, STATE, LATITUDE, LONGITUDE, DISCOVERY_TIME, CONT_TIME from Fires", con)

print(fire_data)

con.close()
# Out:
#          OBJECTID     FOD_ID             FPA_ID  FIRE_YEAR  FIPS_NAME  \
# 0               1          1         FS-1418826       2005     Plumas
# 1               2          2         FS-1418827       2004     Placer
# 2               3          3         FS-1418835       2004  El Dorado
# 3               4          4         FS-1418845       2004     Alpine
# 4               5          5         FS-1418847       2004     Alpine
# ...           ...        ...                ...        ...        ...
# 1880460   1880461  300348363  2015CAIRS29019636       2015       None
# 1880461   1880462  300348373  2015CAIRS29217935       2015       None
# 1880462   1880463  300348375  2015CAIRS28364460       2015       None
# 1880463   1880464  300348377  2015CAIRS29218079       2015       None
# 1880464   1880465  300348399  2015CAIRS26733926       2015       None
#
#                          FIRE_NAME  FIRE_SIZE  DISCOVERY_DATE FIRE_CODE  \
# 0                         FOUNTAIN       0.10       2453403.5      BJ8K
# 1                           PIGEON       0.25       2453137.5      AAC0
# 2                            SLACK       0.10       2453156.5      A32W
# 3                             DEER       0.10       2453184.5      None
# 4                         STEVENOT       0.10       2453184.5      None
# ...                            ...        ...             ...       ...
# 1880460                   ODESSA 2       0.01       2457291.5      None
# 1880461                       None       0.20       2457300.5      None
# 1880462                       None       0.10       2457144.5      None
# 1880463                       None       2.00       2457309.5      None
# 1880464  BARKER BL  BIG_BEAR_LAKE_       0.10       2457095.5      None
#
#           STAT_CAUSE_DESCR  CONT_DATE STATE   LATITUDE   LONGITUDE  \
# 0            Miscellaneous  2453403.5    CA  40.036944 -121.005833
# 1                Lightning  2453137.5    CA  38.933056 -120.404444
# 2           Debris Burning  2453156.5    CA  38.984167 -120.735556
# 3                Lightning  2453189.5    CA  38.559167 -119.913333
# 4                Lightning  2453189.5    CA  38.559167 -119.933056
# ...                    ...        ...   ...        ...         ...
# 1880460  Missing/Undefined  2457291.5    CA  40.481637 -122.389375
# 1880461      Miscellaneous        NaN    CA  37.617619 -120.938570
# 1880462  Missing/Undefined        NaN    CA  37.617619 -120.938570
# 1880463  Missing/Undefined        NaN    CA  37.672235 -120.898356
# 1880464      Miscellaneous        NaN    CA  34.263217 -116.830950
#
#         DISCOVERY_TIME CONT_TIME
# 0                 1300      1730
# 1                 0845      1530
# 2                 1921      2024
# 3                 1600      1400
# 4                 1600      1200
# ...                ...       ...
# 1880460           1726      1843
# 1880461           0126      None
# 1880462           2052      None
# 1880463           2309      None
# 1880464           2128      None
#
# [1880465 rows x 16 columns]

# %%
fire_data = fire_data.dropna(inplace = False)
fire_data['Start Date'] = (pd.to_datetime((fire_data.DISCOVERY_DATE // 1000).astype(int)) + 
                 pd.to_timedelta(fire_data.DISCOVERY_DATE % 1000, unit='D'))
fire_data['End Date'] = (pd.to_datetime((fire_data.CONT_DATE // 1000).astype(int)) + 
                 pd.to_timedelta(fire_data.CONT_DATE % 1000, unit='D'))
fire_data["Start Date"] = pd.DatetimeIndex(fire_data['Start Date']).date
fire_data["End Date"] = pd.DatetimeIndex(fire_data['End Date']).date
fire_data
# Out:
#          OBJECTID     FOD_ID               FPA_ID  FIRE_YEAR  FIPS_NAME  \
# 0               1          1           FS-1418826       2005     Plumas
# 1               2          2           FS-1418827       2004     Placer
# 2               3          3           FS-1418835       2004  El Dorado
# 16             17         17           FS-1418878       2004     Amador
# 17             18         18           FS-1418881       2004  El Dorado
# ...           ...        ...                  ...        ...        ...
# 1804932   1804933  300218435  FWS-2015USNDVCRJP4N       2015     Steele
# 1804933   1804934  300218436  FWS-2015USCATKRJP41       2015   Siskiyou
# 1804934   1804935  300218437  FWS-2015USFLLWRJQM7       2015    Volusia
# 1804935   1804936  300218438  FWS-2015USALBORJQ0Y       2015    Baldwin
# 1804936   1804937  300218439  FWS-2015USFLMIRJQ4R       2015    Volusia
#
#                 FIRE_NAME  FIRE_SIZE  DISCOVERY_DATE FIRE_CODE  \
# 0                FOUNTAIN       0.10       2453403.5      BJ8K
# 1                  PIGEON       0.25       2453137.5      AAC0
# 2                   SLACK       0.10       2453156.5      A32W
# 16                  POWER   16823.00       2453284.5
# 17                  FREDS    7700.00       2453291.5      BHA3
# ...                   ...        ...             ...       ...
# 1804932            ROGERS     160.00       2457145.5      JP4N
# 1804933              HILL       0.20       2457149.5      JP41
# 1804934             SHELL       0.50       2457160.5      JQM7
# 1804935  JEFF FRIEND FIRE      18.00       2457164.5      JQ0Y
# 1804936              OPAL       0.50       2457168.5      JQ4R
#
#           STAT_CAUSE_DESCR  CONT_DATE STATE   LATITUDE   LONGITUDE  \
# 0            Miscellaneous  2453403.5    CA  40.036944 -121.005833
# 1                Lightning  2453137.5    CA  38.933056 -120.404444
# 2           Debris Burning  2453156.5    CA  38.984167 -120.735556
# 16           Equipment Use  2453299.5    CA  38.523333 -120.211667
# 17           Equipment Use  2453295.5    CA  38.780000 -120.260000
# ...                    ...        ...   ...        ...         ...
# 1804932          Lightning  2457146.5    ND  47.306143  -97.648013
# 1804933     Debris Burning  2457149.5    CA  41.943937 -121.564483
# 1804934           Campfire  2457160.5    FL  29.024170  -81.370830
# 1804935  Missing/Undefined  2457168.5    AL  30.244383  -87.806450
# 1804936          Lightning  2457168.5    FL  28.819940  -80.854440
#
#         DISCOVERY_TIME CONT_TIME  Start Date    End Date  Days_Lasted  \
# 0                 1300      1730  1971-02-08  1971-02-08          0.0
# 1                 0845      1530  1970-05-18  1970-05-18          0.0
# 2                 1921      2024  1970-06-06  1970-06-06          0.0
# 16                1415      1000  1970-10-12  1970-10-27          0.0
# 17                1618      1800  1970-10-19  1970-10-23          0.0
# ...                ...       ...         ...         ...          ...
# 1804932           1200      1630  1970-05-26  1970-05-27          0.0
# 1804933           1730      1800  1970-05-30  1970-05-30          0.0
# 1804934           1700      1900  1970-06-10  1970-06-10          0.0
# 1804935           1730      1400  1970-06-14  1970-06-18          0.0
# 1804936           1145      1600  1970-06-18  1970-06-18          0.0
#
#          Time_Lasted
# 0                0.0
# 1                0.0
# 2                0.0
# 16              15.0
# 17               4.0
# ...              ...
# 1804932          1.0
# 1804933          0.0
# 1804934          0.0
# 1804935          4.0
# 1804936          0.0
#
# [164579 rows x 20 columns]

# %%
cause = fire_data.groupby(["STAT_CAUSE_DESCR"])
cause = cause.count()
cause = cause[["FIRE_NAME"]]
cause = cause.rename(columns = {"FIRE_NAME": "Number of Fires"})
cause = cause.sort_values(by=['Number of Fires'])
cause
# Out:
#                    Number of Fires
# STAT_CAUSE_DESCR
# Structure                     2677
# Railroad                      7201
# Fireworks                    10214
# Powerline                    10854
# Smoking                      23069
# Children                     31537
# Missing/Undefined            48822
# Campfire                     51004
# Equipment Use                81278
# Arson                       106209
# Miscellaneous               161361
# Debris Burning              171482
# Lightning                   217568

# %%
pie_cause = cause.plot(kind = "pie", y="Number of Fires", labeldistance = None, figsize=(20,10), fontsize=9, autopct='%1.0f%%', pctdistance=1.1, title= "Cause of Fires from 1992 to 2015")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
fire_num = fire_data[["FIRE_YEAR", "FIRE_NAME"]]
yearly_fire_num = fire_num.groupby(["FIRE_YEAR"])
counted_fire = yearly_fire_num.count() 
counted_fire = counted_fire.rename(columns = {"FIRE_NAME": "Number of Fires"})
counted_fire
# Out:
#            Number of Fires
# FIRE_YEAR
# 1992                 20498
# 1993                 18105
# 1994                 23388
# 1995                 27032
# 1996                 35648
# 1997                 27733
# 1998                 30225
# 1999                 35942
# 2000                 48362
# 2001                 49060
# 2002                 42585
# 2003                 33258
# 2004                 30852
# 2005                 26642
# 2006                 33166
# 2007                 32211
# 2008                 27090
# 2009                 45199
# 2010                 43824
# 2011                 72569
# 2012                 55978
# 2013                 50212
# 2014                 52883
# 2015                 60814

# %%
ax = counted_fire.plot.line()

# %%
fire_size = fire_data[["FIRE_YEAR", "FIRE_SIZE"]]
aver_fire_year = fire_size.groupby(["FIRE_YEAR"]).mean()
aver_fire_year=aver_fire_year.rename(columns = {"FIRE_SIZE": "Average Fire Size (Acres)"})
aver_fire_year
# Out:
#            Average Fire Size (Acres)
# FIRE_YEAR
# 1992                       32.364222
# 1993                       35.356208
# 1994                       54.198875
# 1995                       28.676755
# 1996                       79.460604
# 1997                       52.313024
# 1998                       29.414983
# 1999                       68.039342
# 2000                       79.234760
# 2001                       43.009601
# 2002                       89.923580
# 2003                       65.682790
# 2004                      118.855760
# 2005                      109.082041
# 2006                       88.097768
# 2007                       96.946091
# 2008                       63.324652
# 2009                       77.333752
# 2010                       43.728864
# 2011                      106.277026
# 2012                      129.724037
# 2013                       69.350145
# 2014                       54.218860
# 2015                      137.174526

# %%
ax2 = aver_fire_year.plot.line()

# %%
total_acre = fire_size.groupby(["FIRE_YEAR"]).sum()
total_acre =total_acre.rename(columns = {"FIRE_SIZE": "Total Fire Size (Acres)"})
total_acre
# Out:
#            Total Fire Size (Acres)
# FIRE_YEAR
# 1992                  2.199958e+06
# 1993                  2.191696e+06
# 1994                  4.116676e+06
# 1995                  2.049585e+06
# 1996                  6.005156e+06
# 1997                  3.214635e+06
# 1998                  2.011102e+06
# 1999                  6.080200e+06
# 2000                  7.639499e+06
# 2001                  3.724072e+06
# 2002                  6.803258e+06
# 2003                  4.483573e+06
# 2004                  8.234208e+06
# 2005                  9.665105e+06
# 2006                  1.004350e+07
# 2007                  9.265429e+06
# 2008                  5.406532e+06
# 2009                  6.057166e+06
# 2010                  3.493455e+06
# 2011                  9.623597e+06
# 2012                  9.439888e+06
# 2013                  4.492502e+06
# 2014                  3.673490e+06
# 2015                  1.021827e+07

# %%
ax3 = total_acre.plot.line()

# %%
merged1= pd.merge(total_acre, aver_fire_year, on ="FIRE_YEAR")
merged2 = pd.merge(merged1, counted_fire, on ="FIRE_YEAR")
merged2
# Out:
#            Total Fire Size (Acres)  Average Fire Size (Acres)  Number of Fires
# FIRE_YEAR
# 1992                  2.199958e+06                  32.364222            20498
# 1993                  2.191696e+06                  35.356208            18105
# 1994                  4.116676e+06                  54.198875            23388
# 1995                  2.049585e+06                  28.676755            27032
# 1996                  6.005156e+06                  79.460604            35648
# 1997                  3.214635e+06                  52.313024            27733
# 1998                  2.011102e+06                  29.414983            30225
# 1999                  6.080200e+06                  68.039342            35942
# 2000                  7.639499e+06                  79.234760            48362
# 2001                  3.724072e+06                  43.009601            49060
# 2002                  6.803258e+06                  89.923580            42585
# 2003                  4.483573e+06                  65.682790            33258
# 2004                  8.234208e+06                 118.855760            30852
# 2005                  9.665105e+06                 109.082041            26642
# 2006                  1.004350e+07                  88.097768            33166
# 2007                  9.265429e+06                  96.946091            32211
# 2008                  5.406532e+06                  63.324652            27090
# 2009                  6.057166e+06                  77.333752            45199
# 2010                  3.493455e+06                  43.728864            43824
# 2011                  9.623597e+06                 106.277026            72569
# 2012                  9.439888e+06                 129.724037            55978
# 2013                  4.492502e+06                  69.350145            50212
# 2014                  3.673490e+06                  54.218860            52883
# 2015                  1.021827e+07                 137.174526            60814

# %%
merged2.plot(kind="scatter", x="Average Fire Size (Acres)", y="Number of Fires", grid=True, figsize=(8,8),
              title="Fire Count verus Acres")
# Out:
# <AxesSubplot:title={'center':'Fire Count verus Acres'}, xlabel='Average Fire Size (Acres)', ylabel='Number of Fires'>

# %%
fire_state = fire_data[["STATE", "FIRE_SIZE"]]
state_count = fire_state.groupby(["STATE"]).count()
state_count
# Out:
#        FIRE_SIZE
# STATE
# AK         12843
# AL         66570
# AR         31663
# AZ         71586
# CA        189550
# CO         34157
# CT          4976
# DC            66
# DE           171
# FL         90261
# GA        168867
# HI          9895
# IA          4134
# ID         36698
# IL          2327
# IN          2098
# KS          7673
# KY         27089
# LA         30013
# MA          2626
# MD          3622
# ME         13150
# MI         10502
# MN         44769
# MO         17953
# MS         79230
# MT         40767
# NC        111277
# ND         15201
# NE          7973
# NH          2452
# NJ         25949
# NM         37478
# NV         16956
# NY         80870
# OH          3479
# OK         43239
# OR         61088
# PA          8712
# PR         22081
# RI           480
# SC         81315
# SD         30963
# TN         31154
# TX        142021
# UT         30725
# VA         21833
# VT           456
# WA         33513
# WI         31861
# WV         21967
# WY         14166

# %%
pie_bar = state_count.plot(kind = "bar", y="FIRE_SIZE", figsize=(20,10), title= "Number of Fires per Stae")
plt.show()

# %%
cal_fire = fire_data.loc[fire_data["STATE"] == "CA", :]
cal_fire
# Out:
#          OBJECTID     FOD_ID             FPA_ID  FIRE_YEAR  FIPS_NAME  \
# 0               1          1         FS-1418826       2005     Plumas
# 1               2          2         FS-1418827       2004     Placer
# 2               3          3         FS-1418835       2004  El Dorado
# 3               4          4         FS-1418845       2004     Alpine
# 4               5          5         FS-1418847       2004     Alpine
# ...           ...        ...                ...        ...        ...
# 1880460   1880461  300348363  2015CAIRS29019636       2015       None
# 1880461   1880462  300348373  2015CAIRS29217935       2015       None
# 1880462   1880463  300348375  2015CAIRS28364460       2015       None
# 1880463   1880464  300348377  2015CAIRS29218079       2015       None
# 1880464   1880465  300348399  2015CAIRS26733926       2015       None
#
#                          FIRE_NAME  FIRE_SIZE  DISCOVERY_DATE FIRE_CODE  \
# 0                         FOUNTAIN       0.10       2453403.5      BJ8K
# 1                           PIGEON       0.25       2453137.5      AAC0
# 2                            SLACK       0.10       2453156.5      A32W
# 3                             DEER       0.10       2453184.5      None
# 4                         STEVENOT       0.10       2453184.5      None
# ...                            ...        ...             ...       ...
# 1880460                   ODESSA 2       0.01       2457291.5      None
# 1880461                       None       0.20       2457300.5      None
# 1880462                       None       0.10       2457144.5      None
# 1880463                       None       2.00       2457309.5      None
# 1880464  BARKER BL  BIG_BEAR_LAKE_       0.10       2457095.5      None
#
#           STAT_CAUSE_DESCR  CONT_DATE STATE
# 0            Miscellaneous  2453403.5    CA
# 1                Lightning  2453137.5    CA
# 2           Debris Burning  2453156.5    CA
# 3                Lightning  2453189.5    CA
# 4                Lightning  2453189.5    CA
# ...                    ...        ...   ...
# 1880460  Missing/Undefined  2457291.5    CA
# 1880461      Miscellaneous        NaN    CA
# 1880462  Missing/Undefined        NaN    CA
# 1880463  Missing/Undefined        NaN    CA
# 1880464      Miscellaneous        NaN    CA
#
# [189550 rows x 12 columns]

# %%
fire_num = cal_fire[["FIRE_YEAR", "FIRE_NAME"]]
yearly_fire_num = fire_num.groupby(["FIRE_YEAR"])
counted_fire = yearly_fire_num.count() 
counted_fire = counted_fire.rename(columns = {"FIRE_NAME": "Number of Fires"})
counted_fire
# Out:
#            Number of Fires
# FIRE_YEAR
# 1992                  9076
# 1993                  7444
# 1994                  7550
# 1995                  7323
# 1996                  9173
# 1997                  7930
# 1998                  6864
# 1999                  8910
# 2000                  6977
# 2001                  8182
# 2002                  7133
# 2003                  7913
# 2004                  7418
# 2005                  6678
# 2006                  7892
# 2007                  9581
# 2008                  7411
# 2009                  6664
# 2010                  5611
# 2011                  6266
# 2012                  6461
# 2013                  6156
# 2014                  4385
# 2015                  5559

# %%
ax = counted_fire.plot.line()

# %%
fire_size = cal_fire[["FIRE_YEAR", "FIRE_SIZE"]]
aver_fire_year = fire_size.groupby(["FIRE_YEAR"]).mean()
aver_fire_year=aver_fire_year.rename(columns = {"FIRE_SIZE": "Average Fire Size (Acres)"})
aver_fire_year
# Out:
#            Average Fire Size (Acres)
# FIRE_YEAR
# 1992                       27.364516
# 1993                       38.874885
# 1994                       47.139438
# 1995                       29.273635
# 1996                       77.086068
# 1997                       40.928916
# 1998                       23.311932
# 1999                       90.249540
# 2000                       36.215565
# 2001                       42.798423
# 2002                       72.191602
# 2003                      130.413882
# 2004                       40.589912
# 2005                       38.741370
# 2006                       98.260421
# 2007                      102.974251
# 2008                      184.678926
# 2009                       65.612398
# 2010                       20.939584
# 2011                       22.458178
# 2012                      106.099700
# 2013                       66.652561
# 2014                       84.212932
# 2015                      115.238100

# %%
ax2 = aver_fire_year.plot.line()

# %%
total_acre = fire_size.groupby(["FIRE_YEAR"]).sum()
total_acre =total_acre.rename(columns = {"FIRE_SIZE": "Total Fire Size (Acres)"})
total_acre
# Out:
#            Total Fire Size (Acres)
# FIRE_YEAR
# 1992                    296439.800
# 1993                    321495.300
# 1994                    407944.700
# 1995                    216068.700
# 1996                    707110.500
# 1997                    324566.300
# 1998                    160013.100
# 1999                    804123.400
# 2000                    252676.000
# 2001                    350176.700
# 2002                    514942.700
# 2003                   1031965.050
# 2004                    301095.970
# 2005                    258714.870
# 2006                    812711.940
# 2007                   1045291.620
# 2008                   1430153.600
# 2009                    455350.040
# 2010                    120947.040
# 2011                    192286.920
# 2012                    764766.640
# 2013                    581410.292
# 2014                    546878.780
# 2015                    848728.610

# %%
ax3 = total_acre.plot.line()

# %%
fire_data["Days_Lasted"] = fire_data["End Date"] - fire_data["Start Date"]
# fire_data["Time_Lasted"] = fire_data["CONT_TIME"] - fire_data["DISCOVERY_TIME"]

fire_data["Days_Lasted"] = fire_data["Days_Lasted"].dt.components.days

fire_data = fire_data['DISCOVERY_TIME'].apply(int_to_time)
fire_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-4464ba0135e2> in <module>
#       4 fire_data["Days_Lasted"] = fire_data["Days_Lasted"].dt.components.days
#       5
# ----> 6 fire_data = fire_data['DISCOVERY_TIME'].apply(int_to_time)
#       7 fire_data
#
# NameError: name 'int_to_time' is not defined

# %%
fire_size_date = fire_data.loc[fire_data["Days_Lasted"]>0, :]

day_last = fire_size_date["Days_Lasted"]
fire_size = fire_size_date["FIRE_SIZE"]
plt.scatter(x = day_last, y = fire_size, c = "DarkBlue")


correlation = st.pearsonr(day_last,fire_size)
print(f"The correlation between size and time is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(day_last,fire_size)
regress_values = day_last * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(day_last,regress_values,"r-")
# Out:
# The correlation between size and time is 0.17

# %%
# fire_data = fire_data.dropna(inplace = False)

# %%
# fire_data['Start Date'] = (pd.to_datetime((fire_data.DISCOVERY_DATE // 1000).astype(int)) + 
#                  pd.to_timedelta(fire_data.DISCOVERY_DATE % 1000, unit='D'))
# fire_data['End Date'] = (pd.to_datetime((fire_data.CONT_DATE // 1000).astype(int)) + 
#                  pd.to_timedelta(fire_data.CONT_DATE % 1000, unit='D'))
# fire_data.head()
# Out:
#     OBJECTID  FOD_ID      FPA_ID  FIRE_YEAR  FIPS_NAME FIRE_NAME  FIRE_SIZE  \
# 0          1       1  FS-1418826       2005     Plumas  FOUNTAIN       0.10
# 1          2       2  FS-1418827       2004     Placer    PIGEON       0.25
# 2          3       3  FS-1418835       2004  El Dorado     SLACK       0.10
# 16        17      17  FS-1418878       2004     Amador     POWER   16823.00
# 17        18      18  FS-1418881       2004  El Dorado     FREDS    7700.00
#
#     DISCOVERY_DATE FIRE_CODE STAT_CAUSE_DESCR  CONT_DATE STATE   LATITUDE  \
# 0        2453403.5      BJ8K    Miscellaneous  2453403.5    CA  40.036944
# 1        2453137.5      AAC0        Lightning  2453137.5    CA  38.933056
# 2        2453156.5      A32W   Debris Burning  2453156.5    CA  38.984167
# 16       2453284.5              Equipment Use  2453299.5    CA  38.523333
# 17       2453291.5      BHA3    Equipment Use  2453295.5    CA  38.780000
#
#      LONGITUDE                    Start Date                      End Date
# 0  -121.005833 1971-02-08 12:00:00.000002453 1971-02-08 12:00:00.000002453
# 1  -120.404444 1970-05-18 12:00:00.000002453 1970-05-18 12:00:00.000002453
# 2  -120.735556 1970-06-06 12:00:00.000002453 1970-06-06 12:00:00.000002453
# 16 -120.211667 1970-10-12 12:00:00.000002453 1970-10-27 12:00:00.000002453
# 17 -120.260000 1970-10-19 12:00:00.000002453 1970-10-23 12:00:00.000002453

# %%
air_quality = fire_data[["FIRE_CODE", "LATITUDE", "LONGITUDE", "Start Date", "End Date"]]
air_quality["Start Date"] = pd.DatetimeIndex(air_quality['Start Date']).date
air_quality["End Date"] = pd.DatetimeIndex(air_quality['End Date']).date
air_quality["Start Month"] = pd.DatetimeIndex(air_quality['Start Date']).month
air_quality["Start Day"] = pd.DatetimeIndex(air_quality['Start Date']).day
air_quality["End Year"] = pd.DatetimeIndex(air_quality['End Date']).year
air_quality["End Month"] = pd.DatetimeIndex(air_quality['End Date']).month
air_quality["End Day"] = pd.DatetimeIndex(air_quality['End Date']).day

# air_quality['Start Date'] = f"{air_quality["Start Year"]}-{air_quality["Start Month"]}-{air_quality["Start Day"]}"
air_quality
# Out:
# <ipython-input-83-79c79652154e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   air_quality["Start Date"] = pd.DatetimeIndex(air_quality['Start Date']).date
# <ipython-input-83-79c79652154e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   air_quality["Start Month"] = pd.DatetimeIndex(air_quality['Start Date']).month
# <ipython-input-83-79c79652154e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   air_quality["Start Day"] = pd.DatetimeIndex(air_quality['Start Date']).day
# <ipython-input-83-79c79652154e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   air_quality["End Year"] = pd.DatetimeIndex(air_quality['End Date']).year
# <ipython-input-83-79c79652154e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   air_quality["End Month"] = pd.DatetimeIndex(air_quality['End Date']).month
# <ipython-input-83-79c79652154e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   air_quality["End Day"] = pd.DatetimeIndex(air_quality['End Date']).day
#         FIRE_CODE   LATITUDE   LONGITUDE  Start Month  Start Day  End Year  \
# 0            BJ8K  40.036944 -121.005833            2          8      1971
# 1            AAC0  38.933056 -120.404444            5         18      1970
# 2            A32W  38.984167 -120.735556            6          6      1970
# 16                 38.523333 -120.211667           10         12      1970
# 17           BHA3  38.780000 -120.260000           10         19      1970
# ...           ...        ...         ...          ...        ...       ...
# 1804932      JP4N  47.306143  -97.648013            5         26      1970
# 1804933      JP41  41.943937 -121.564483            5         30      1970
# 1804934      JQM7  29.024170  -81.370830            6         10      1970
# 1804935      JQ0Y  30.244383  -87.806450            6         14      1970
# 1804936      JQ4R  28.819940  -80.854440            6         18      1970
#
#          End Month  End Day
# 0                2        8
# 1                5       18
# 2                6        6
# 16              10       27
# 17              10       23
# ...            ...      ...
# 1804932          5       27
# 1804933          5       30
# 1804934          6       10
# 1804935          6       18
# 1804936          6       18
#
# [165175 rows x 8 columns]

# %%
for index, row in air_quality():
    
    Lat = row["Latitude"]
    Lng = row["Longitude"]
    
    s_year = row["Start Year"]
    s_month = row["Start_Month"]
    s_day = row["Start_Day"]
    e_year = row["Start Year"]
    e_month = row["Start_Month"]
    e_day = row["Start_Day"]
    
    date = f"{s_year}-{s_month}-{s_day}"
    url = f"https://www.airnowapi.org/aq/observation/latLong/historical/?format=application/json&latitude={Lat}&longitude={Lng}&date={date}T00-0000&distance=25&API_KEY={air_key}"
    s_response = requests.get(url).json()
    
    date = f"{e_year}-{e_month}-{e_day}"
    url = f"https://www.airnowapi.org/aq/observation/latLong/historical/?format=application/json&latitude={Lat}&longitude={Lng}&date={date}T00-0000&distance=25&API_KEY={air_key}"
    e_response = requests.get(url).json()
# Out:
# []

# %%
# air_quality["Start Month"] = pd.DatetimeIndex(air_quality['Start Date']).month
# air_quality["Start Day"] = pd.DatetimeIndex(air_quality['Start Date']).day
# air_quality["End Year"] = pd.DatetimeIndex(air_quality['End Date']).year
# air_quality["End Month"] = pd.DatetimeIndex(air_quality['End Date']).month
# air_quality["End Day"] = pd.DatetimeIndex(air_quality['End Date']).day
